# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('Cleaned_DataSet.csv')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
df.shape
# Out:
# (10840, 16)

# %%
df.sample(5)
# Out:
#                            App       Category  Rating   Reviews  Size  \
# 4273      J. Polep Plus Mobile   PRODUCTIVITY     NaN         0  44.0
# 1074              Credit Karma        FINANCE     4.7    706301   NaN
# 6637            Add-On: bq (c)   PRODUCTIVITY     NaN        17   1.2
# 1966          Candy Crush Saga           GAME     4.4  22430188  74.0
# 9050  Mircules DX Cluster Lite  COMMUNICATION     4.5        51  21.0
#
#        Installs  Type  Price Content Rating         Genres Last Updated  \
# 4273        100  Free    0.0       Everyone   Productivity   2018-03-26
# 1074   10000000  Free    0.0       Everyone        Finance   2018-07-31
# 6637       1000  Free    0.0       Everyone   Productivity   2015-05-19
# 1966  500000000  Free    0.0       Everyone         Casual   2018-07-05
# 9050       5000  Free    0.0       Everyone  Communication   2016-05-10
#
#              Current Ver         Android Ver  Day  Month  Year
# ...

# %%
df.describe().T
# Out:
#             count          mean           std      min     25%       50%  \
# Rating     9366.0  4.191757e+00  5.152189e-01     1.00     4.0       4.3
# Reviews   10840.0  4.441529e+05  2.927761e+06     0.00    38.0    2094.0
# Size       9145.0  2.150653e+01  2.259602e+01     0.01     4.9      13.0
# Installs  10840.0  1.546434e+07  8.502936e+07     0.00  1000.0  100000.0
# Price     10840.0  1.027368e+00  1.594970e+01     0.00     0.0       0.0
# Day       10840.0  1.560904e+01  9.561621e+00     1.00     6.0      16.0
# Month     10840.0  6.422325e+00  2.578388e+00     1.00     5.0       7.0
# Year      10840.0  2.017400e+03  1.100914e+00  2010.00  2017.0    2018.0
#
#                 75%           max
# Rating          4.5  5.000000e+00
# Reviews     54775.5  7.815831e+07
# Size           30.0  1.000000e+02
# Installs  5000000.0  1.000000e+09
# Price           0.0  4.000000e+02
# Day            24.0  3.100000e+01
# Month           8.0  1.200000e+01
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
#  13  Day             10840 non-null  int64
#  14  Month           10840 non-null  int64
#  15  Year            10840 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# ...

# %%
df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size              1695
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# Day                  0
# Month                0
# Year                 0
# dtype: int64

# %%
df.describe(include = "all").T
# Out:
#                   count unique                 top   freq             mean  \
# App               10840   9659              ROBLOX      9              NaN
# Category          10840     33              FAMILY   1972              NaN
# Rating           9366.0    NaN                 NaN    NaN         4.191757
# Reviews         10840.0    NaN                 NaN    NaN    444152.896033
# Size             9145.0    NaN                 NaN    NaN        21.506534
# Installs        10840.0    NaN                 NaN    NaN  15464338.882565
# Type              10839      2                Free  10039              NaN
# Price           10840.0    NaN                 NaN    NaN         1.027368
# Content Rating    10840      6            Everyone   8714              NaN
# Genres            10840    119               Tools    842              NaN
# Last Updated      10840   1377          2018-08-03    326              NaN
# ...

# %%
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10767                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#Distribution of Categorical and Numerical Columns
numeric_feature = [feature for feature in df.columns if df[feature].dtype!= "O"]
categorical_feature = [feature for feature in df.columns if df[feature].dtype =="O"]

# %%
df_num = df[numeric_feature]

# %%
df_num
# Out:
#        Rating  Reviews  Size  Installs  Price  Day  Month  Year
# 0         4.1      159  19.0     10000    0.0    7      1  2018
# 1         3.9      967  14.0    500000    0.0   15      1  2018
# 2         4.7    87510   8.7   5000000    0.0    1      8  2018
# 3         4.5   215644  25.0  50000000    0.0    8      6  2018
# 4         4.3      967   2.8    100000    0.0   20      6  2018
# ...       ...      ...   ...       ...    ...  ...    ...   ...
# 10835     4.5       38  53.0      5000    0.0   25      7  2017
# 10836     5.0        4   3.6       100    0.0    6      7  2018
# 10837     NaN        3   9.5      1000    0.0   20      1  2017
# 10838     4.5      114   NaN      1000    0.0   19      1  2015
# 10839     4.5   398307  19.0  10000000    0.0   25      7  2018
#
# [10357 rows x 8 columns]

# %%
df_cat = df[categorical_feature]

# %%
df_cat
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# Chceking the distribution of numerical feature
plt.figure(figsize=(15,15))
plt.suptitle("Univariate Analysis of Numerical Feature", fontsize = 20, fontweight = 'bold', alpha = 0.8, y=1.)


for i in range(0, len(numeric_feature)):
    plt.subplot(5,3,i+1)
    sns.kdeplot(x=df[numeric_feature[i]],shade=True, color ='r')
    plt.xlabel(numeric_feature[i])
    plt.tight_layout()

# %%
df_cat
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_cat['Type'].value_counts()
# Out:
# Free    9591
# Paid     765
# Name: Type, dtype: int64

# %%
sns.countplot(df_cat['Type'])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
sns.countplot(df_cat['Content Rating'])
# Out:
# <AxesSubplot:xlabel='Content Rating', ylabel='count'>

# %%
plt.figure(figsize=(25,35))
plt.suptitle("Univariate Analysis of Categorical Feature", fontsize = 20, fontweight = 'bold', alpha = 0.8, y=1.)
category= ['Type', 'Content Rating']

for i in range(0, len(category)):
    plt.subplot(5,3,i+1)
    sns.countplot(x=df[category[i]],palette = "Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %%
# To know the most popular categories in category column
df_cat['Category'].value_counts().plot.pie(figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='Category'>

# %%
# Fetching Top 10 Category
df_cat['Category'].value_counts().iloc[0:10]
# Out:
# FAMILY             1943
# GAME               1121
# TOOLS               843
# BUSINESS            427
# MEDICAL             408
# PRODUCTIVITY        407
# PERSONALIZATION     388
# LIFESTYLE           373
# COMMUNICATION       366
# FINANCE             360
# Name: Category, dtype: int64

# %%
# Which category has highest number of installation

df.groupby(['Category'])["Installs"].sum().sort_values(ascending= False).plot(kind= "bar", figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
(df['Rating'] ==5).value_counts()
# Out:
# False    10086
# True       271
# Name: Rating, dtype: int64

# %%
# Out:
# Rating
# False    Photo Editor & Candy Camera & Grid & ScrapBook...
# True     Hojiboy Tojiboyev Life HacksAmerican Girls Mob...
# Name: App, dtype: object
